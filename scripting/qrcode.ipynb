# %%
# !pip install segno
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 41.7 kB/s eta 0:00:00a 0:00:01m
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# animated_qrcode.py

import segno
from urllib.request import urlopen

# %%
slts_qrcode = segno.make_qr("https://nico-djiembou.netlify.app")

# %%
slts_qrcode.save(
    "victor_qrcode.png",
    scale=5,
    border=1,
)

# %%
# !pip install pillow qrcode-artistic
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
qrcode = segno.make_qr("https://nico-djiembou.netlify.app")

# %%
nirvana_url = urlopen("https://nico-djiembou.netlify.app/assets/img/profile-img.jpg")
qrcode.to_artistic(
    background=nirvana_url,
    target="victor_qrcode_bg.png",
    scale=5,
    border=1,
)
